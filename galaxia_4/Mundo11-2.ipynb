# %% [markdown]
# # Mundo 11
#
# ### Leitura e extração de dados

# %%
# ! pip install yfinance==0.2.65
import pandas as pd
import yfinance as yf 
from datetime import datetime

# %%
acao = "WEGE3.SA"

dados = yf.download(tickers= acao)

dados
# Out:
# /var/folders/hc/gmsnyqp935sbw3_735znp87r0000gp/T/ipykernel_42818/4031395727.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   dados = yf.download(tickers= acao)
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker       WEGE3.SA   WEGE3.SA   WEGE3.SA   WEGE3.SA  WEGE3.SA
# Date
# 2025-06-30  42.577217  42.925560  42.029825  42.109448  10282300
# 2025-07-01  42.298546  42.786225  42.159210  42.477693   7110200
# 2025-07-02  42.228878  42.915606  41.910395  42.079588   7025100
# 2025-07-03  42.507549  42.746413  42.029825  42.298546   6963500
# 2025-07-04  42.796173  43.174373  42.587169  42.666788   3488100
# 2025-07-07  42.129353  42.905654  42.039779  42.796175   4161300
# 2025-07-08  40.417503  42.487642  40.248307  42.487642  11029800
# 2025-07-09  39.919876  40.357789  39.770586  40.308027  11678900
# ...

# %%
acao = "WEGE3.SA"

dados = yf.download(tickers= acao, start = "2010-12-31", end = datetime.now())

dados
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2011-01-03   3.254437   3.323964   3.233727   3.251479   2.551675  2290288
# 2011-01-04   3.286982   3.292899   3.181952   3.195266   2.507560  2618824
# 2011-01-05   3.195266   3.233727   3.150887   3.152366   2.473893  3096756
# 2011-01-06   3.177514   3.183431   3.100591   3.118343   2.447194  2873676
# 2011-01-07   3.162721   3.167159   3.112426   3.122781   2.450676  3000764
# ...               ...        ...        ...        ...        ...      ...
# 2023-01-10  37.520000  37.910000  37.080002  37.549999  37.549999  6556000
# 2023-01-11  37.490002  38.700001  37.200001  38.599998  38.599998  5982900
# 2023-01-12  38.540001  38.990002  38.200001  38.509998  38.509998  5376000
# 2023-01-13  38.189999  39.360001  37.919998  38.970001  38.970001  4957200
# ...

# %%
acao = "WEGE3.SA"

dados = yf.download(tickers= acao, start = "2010-12-31", end = datetime.now(), 
                           interval = '1wk') 

#pode inventar moda tipo isso, mas deixa pra calcular qualquer coisa dentro do proprio pandas. 

dados
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2010-12-27   3.224852   3.224852   3.224852   3.224852   2.530779         0.0
# 2011-01-03   3.254437   3.323964   3.100591   3.122781   2.450675  13880308.0
# 2011-01-10   3.134615   3.218934   3.113905   3.165680   2.484343  10935652.0
# 2011-01-17   3.152366   3.181952   3.082840   3.088757   2.423975  13840424.0
# 2011-01-24   3.099112   3.115384   2.889053   2.921597   2.292792  16892564.0
# ...               ...        ...        ...        ...        ...         ...
# 2022-12-19        NaN        NaN        NaN        NaN        NaN         NaN
# 2022-12-25  38.330002  39.330002  37.779999  38.509998  38.509998  18929800.0
# 2023-01-01  38.500000  38.500000  36.660000  38.029999  38.029999  25582700.0
# 2023-01-08  38.000000  39.360001  37.080002  38.970001  38.970001  28602700.0
# ...

# %%
#puxar ddos várias ações

acao = ["META", "NKE", "GOOGL", "AMZN"]

dados = yf.download(tickers= acao, start = "2010-12-31", end = datetime.now())  
                           
dados
# Out:
# /var/folders/hc/gmsnyqp935sbw3_735znp87r0000gp/T/ipykernel_42818/3069623607.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   dados = yf.download(tickers= acao, start = "2010-12-31", end = datetime.now())
# [*********************100%***********************]  4 of 4 completed
# Price            Close                                           High  \
# Ticker            AMZN       GOOGL        META        NKE        AMZN
# Date
# 2010-12-31    9.000000   14.775500         NaN  17.807165    9.115000
# 2011-01-03    9.211000   15.033710         NaN  17.946842    9.300000
# 2011-01-04    9.250500   14.978238         NaN  17.504890    9.385000
# 2011-01-05    9.371000   15.151126         NaN  17.619543    9.372500
# 2011-01-06    9.293000   15.261326         NaN  17.461115    9.370500
# ...                ...         ...         ...        ...         ...
# 2025-07-25  231.440002  193.179993  712.679993  76.269997  232.479996
# ...

# %%
#dados['Adj Close']['META']

dados['Adj Close']
# Out:
# Date
# 2010-12-31           NaN
# 2011-01-03           NaN
# 2011-01-04           NaN
# 2011-01-05           NaN
# 2011-01-06           NaN
#                  ...
# 2023-01-09    129.470001
# 2023-01-10    132.990005
# 2023-01-11    132.889999
# 2023-01-12    136.710007
# 2023-01-13    136.979996
# Name: META, Length: 3030, dtype: float64

# %%
#puxar ddos várias ações

acao = ["RPAD5.SA", "CASH3.SA", "VALE3.SA", "ATOM3.SA"]

dados = yf.download(tickers = acao, 
                           start = "2018-12-31", end = datetime.now())['Adj Close']
                           
dados.head(50)
# Out:
# [*********************100%***********************]  4 of 4 completed
#             ATOM3.SA  CASH3.SA  RPAD5.SA   VALE3.SA
# Date
# 2019-01-02  2.060647       NaN  4.451818  37.054115
# 2019-01-03  2.143404       NaN  4.851542  35.538303
# 2019-01-04  2.102026       NaN  4.851542  37.851913
# 2019-01-07  2.126853       NaN  4.851542  37.648842
# 2019-01-08  2.110301       NaN  4.851542  38.011475
# 2019-01-09  2.135128       NaN  4.851542  38.939823
# 2019-01-10  2.060647       NaN  4.851542  38.511913
# 2019-01-11  2.077199       NaN  4.851542  37.989716
# 2019-01-14  2.209610       NaN  4.851542  38.149273
# 2019-01-15  2.201334       NaN  4.851542  37.967957
# 2019-01-16  2.143404       NaN  4.851542  38.185539
# 2019-01-17  2.135128       NaN  4.851542  39.331470
# 2019-01-18  2.176507       NaN  4.851542  39.715862
# 2019-01-21  2.193058       NaN  4.686950  40.093006
# 2019-01-22  2.093750       NaN  4.686950  39.947948
# 2019-01-23  2.068923       NaN  5.008296  40.361355
# ...

# %% [markdown]
# # Exercícios
#
# * Exercício 59: Puxe as cotações do Ibovespa desde 1 de junho de 1994 através do Yahoo Finance. Dica: vá no site no yahoo finance e procure pelo ticker do Ibovespa na plataforma.
# * Exercício 60: Puxe os dados de fechamento ajustado da Ambev, Weg, RaiaDrogasil, Pão de Açúcar e Meliuz desde 31/12/2018.

# %%
acao = '^BVSP'

dados = yf.download(tickers= acao, start = "1994-06-01", end = datetime.now())

dados
# Out:
# /var/folders/hc/gmsnyqp935sbw3_735znp87r0000gp/T/ipykernel_42818/1125797239.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   dados = yf.download(tickers= acao, start = "1994-06-01", end = datetime.now())
# [*********************100%***********************]  1 of 1 completed
# Price               Close           High            Low           Open  \
# Ticker              ^BVSP          ^BVSP          ^BVSP          ^BVSP
# Date
# 1994-06-01    2526.500000    2532.699951    2437.100098    2467.199951
# 1994-06-03    2696.000000    2714.000000    2526.500000    2526.500000
# 1994-06-06    2908.699951    2922.100098    2695.800049    2696.000000
# 1994-06-07    2920.500000    2976.000000    2887.699951    2908.699951
# 1994-06-08    2821.800049    2965.000000    2818.199951    2920.500000
# ...                   ...            ...            ...            ...
# 2025-07-25  133524.000000  134204.000000  133285.000000  133820.000000
# ...

# %%
# * Exercício 60: Puxe os dados de fechamento ajustado da Ambev, Weg, RaiaDrogasil, Pão de Açúcar e Meliuz desde 31/12/2018.

acoes = ["WEGE3.SA", "ABEV3.SA", "RADL3.SA", "PCAR3.SA", "CASH3.SA"]

fechamento_ajustado = yf.download(
   tickers = acoes,
   start = '2018-12-31',
   end = datetime.now()
)['Close'] 

# Adj Close não existe mais como coluna separada
# Close agora é automaticamente ajustado (por isso o warning sobre auto_adjust=True)

fechamento_ajustado
# Out:
# /var/folders/hc/gmsnyqp935sbw3_735znp87r0000gp/T/ipykernel_42818/1328390520.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   fechamento_ajustado = yf.download(
# [*********************100%***********************]  5 of 5 completed
# Price           Close                                               High  \
# Ticker       ABEV3.SA CASH3.SA PCAR3.SA   RADL3.SA   WEGE3.SA   ABEV3.SA
# Date
# 2019-01-02  12.336809      NaN  9.34339  10.162501   8.122387  12.451392
# 2019-01-03  12.474311      NaN  9.34339  10.139203   8.307602  12.474311
# 2019-01-04  12.642365      NaN  9.34339  10.284381   8.402467  12.749311
# 2019-01-07  12.588892      NaN  9.34339  10.054965   8.271464  12.703475
# 2019-01-08  12.336809      NaN  9.34339  10.422391   8.203702  12.756949
# ...               ...      ...      ...        ...        ...        ...
# 2025-07-25  13.470000     5.90  3.50000  14.040000  35.998547  13.600000
# ...

# %%
#gabarito 59

ibovespa = yf.download(tickers= '^BVSP', 
                              start = "1994-06-01", end = datetime.now())['Close']
                           
print(ibovespa)

valores = ibovespa.values.flatten()  # Converte para array 1D
ultimo = valores[-1]
primeiro = valores[0]
retorno = ultimo / primeiro - 1
retorno
# Out:
# /var/folders/hc/gmsnyqp935sbw3_735znp87r0000gp/T/ipykernel_42818/3630307763.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ibovespa = yf.download(tickers= '^BVSP',
# [*********************100%***********************]  1 of 1 completed
# Ticker              ^BVSP
# Date
# 1994-06-01    2526.500000
# 1994-06-03    2696.000000
# 1994-06-06    2908.699951
# 1994-06-07    2920.500000
# 1994-06-08    2821.800049
# ...                   ...
# 2025-07-25  133524.000000
# 2025-07-28  132129.000000
# 2025-07-29  132726.000000
# 2025-07-30  133990.000000
# 2025-07-31  133037.234375
#
# [7717 rows x 1 columns]
# np.float64(51.656732386700966)

# %%
#gabarito 60

acoes = ["WEGE3.SA", "ABEV3.SA", "RADL3.SA", "PCAR3.SA", "CASH3.SA"]

banco_de_dados = yf.download(tickers= acoes, 
                           start = "2018-12-31", end = datetime.now())['Close']
                           
banco_de_dados
# Out:
# /var/folders/hc/gmsnyqp935sbw3_735znp87r0000gp/T/ipykernel_42818/570233295.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   banco_de_dados = yf.download(tickers= acoes,
# [*********************100%***********************]  5 of 5 completed
# Ticker       ABEV3.SA  CASH3.SA  PCAR3.SA   RADL3.SA   WEGE3.SA
# Date
# 2019-01-02  12.336810       NaN   9.34339  10.162504   8.122386
# 2019-01-03  12.474310       NaN   9.34339  10.139204   8.307603
# 2019-01-04  12.642365       NaN   9.34339  10.284383   8.402469
# 2019-01-07  12.588893       NaN   9.34339  10.054963   8.271464
# 2019-01-08  12.336810       NaN   9.34339  10.422390   8.203697
# ...               ...       ...       ...        ...        ...
# 2025-07-25  13.470000      5.90   3.50000  14.040000  35.998547
# 2025-07-28  13.060000      6.16   3.52000  13.790000  36.730000
# 2025-07-29  13.190000      5.82   3.45000  13.850000  36.580002
# ...

# %% [markdown]
# # Mundo 12
#
# Agora que você puxou dados do mercado financeiro, que tal puxar dados sobre a economia americana?
